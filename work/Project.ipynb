# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import warnings
from io import StringIO
warnings.simplefilter(action='ignore', category=FutureWarning)

# %config InlineBackend.figure_format ='retina'

df = pd.read_csv('MLB Songs Data - Sheet1 (3).csv',delimiter=',',engine='python')
newdata = pd.read_csv('DF_MLB_GEO.csv',delimiter=',',engine='python')
df['POP']=df["Popularity'"]
df['DAN']=df["Danceability'"]

# %%
data.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [2], in <cell line: 1>()
# ----> 1 data.columns
#
# NameError: name 'data' is not defined

# %%
info = """
Team,League,Games,At Bats,Runs,Hits,Doubles,Triples,Homeruns,RBI,Walks,Strikeouts,Stolen Bases,Caught Stealing,Batting Avg,On Base %,Slugging %,On-Base plus Slugging
Blue Jays,AL,162,5476,846,1455,285,13,262,816,496,1218,81,20,.266,.330,.466,.796
Astros,AL,162,5593,863,1496,299,14,221,834,569,1222,53,16,.267,.339,.444,.783
Red Sox,AL,162,5495,829,1434,330,23,219,783,512,1386,40,21,.261,.328,.449,.777
Giants,NL,162,5462,804,1360,271,25,241,768,602,1461,66,14,.249,.329,.440,.769
Reds,NL,162,5423,786,1352,295,13,222,756,553,1425,36,24,.249,.328,.431,.759
Dodgers,NL,162,5445,830,1330,247,24,237,799,613,1408,65,17,.244,.330,.429,.759
White Sox,AL,162,5357,796,1373,275,22,190,757,586,1389,57,20,.256,.336,.422,.758
Braves,NL,161,5363,790,1307,269,20,239,762,549,1453,59,19,.244,.319,.435,.754
Nationals,NL,162,5385,724,1388,272,20,182,686,573,1303,56,26,.258,.337,.417,.754
Rays,AL,162,5507,857,1336,288,36,222,810,585,1542,88,42,.243,.321,.429,.750
Twins,AL,162,5431,729,1311,271,17,228,690,525,1405,54,15,.241,.314,.423,.737
Rockies,NL,161,5374,739,1338,275,34,182,709,491,1356,76,23,.249,.317,.414,.731
Yankees,AL,162,5331,711,1266,213,12,222,666,621,1482,63,18,.237,.322,.407,.729
Phillies,NL,162,5366,734,1288,262,24,198,700,564,1402,77,19,.240,.318,.408,.726
Cardinals,NL,162,5351,706,1303,261,22,198,678,478,1341,89,22,.244,.313,.412,.725
Athletics,AL,162,5395,743,1284,271,19,199,698,545,1349,88,20,.238,.317,.406,.723
Padres,NL,162,5384,729,1305,273,21,180,695,586,1324,110,39,.242,.321,.401,.722
Cubs,NL,162,5306,705,1255,225,26,210,672,502,1596,86,37,.237,.312,.407,.719
Angels,AL,162,5437,723,1331,265,23,190,691,464,1394,79,26,.245,.310,.407,.717
Brewers,NL,162,5362,738,1251,255,18,194,700,586,1465,82,21,.233,.317,.396,.713
Indians,AL,162,5332,717,1269,248,22,203,686,453,1387,109,17,.238,.303,.407,.710
Tigers,AL,162,5376,697,1299,236,37,179,675,490,1514,88,25,.242,.308,.399,.707
Orioles,AL,162,5420,659,1296,266,15,195,632,451,1454,54,23,.239,.304,.402,.706
Mets,NL,162,5210,636,1243,228,18,176,604,495,1392,54,26,.239,.315,.391,.706
Royals,AL,162,5427,686,1349,251,29,163,647,421,1258,124,33,.249,.306,.396,.702
Diamondbacks,NL,162,5489,679,1297,308,31,144,644,537,1465,43,16,.236,.309,.382,.691
Mariners,AL,162,5355,697,1209,233,11,199,673,535,1492,64,24,.226,.303,.385,.688
Pirates,NL,162,5336,609,1261,240,35,124,570,529,1328,60,30,.236,.309,.364,.673
Marlins,NL,162,5348,623,1244,226,23,158,594,450,1553,106,29,.233,.298,.372,.670
Rangers,AL,162,5405,625,1254,225,24,167,598,433,1381,106,29,.232,.294,.375,.669
"""


info = StringIO(info)

info = pd.read_csv(info)




info2 = """
Rk,Team,W,L,W-L%,R,RA,Rdiff,SOS,SRS,pythWL,Luck,vEast,vCent,vWest,Inter,Home,Road,ExInn,1Run,vRHP,vLHP,≥.500,<.500
1,Giants,107,55,.660,5.0,3.7,1.3,-0.1,1.2,103-59,4,21-11,20-14,53-23,13-7,54-27,53-28,10-9,31-17,80-35,27-20,35-28,72-27
2,Dodgers,106,56,.654,5.1,3.5,1.7,-0.1,1.6,109-53,-3,24-9,20-13,50-26,12-8,58-23,48-33,6-13,24-24,73-42,33-14,35-27,71-29
3,Rays,100,62,.617,5.3,4.0,1.3,0.0,1.3,101-61,-1,51-25,19-13,15-19,15-5,52-29,48-33,7-12,20-25,62-35,38-27,48-42,52-20
4,Brewers,95,67,.586,4.6,3.8,0.7,-0.3,0.4,93-69,2,17-14,47-29,23-12,8-12,45-36,50-31,10-9,21-15,75-48,20-19,32-36,63-31
5,Astros,95,67,.586,5.3,4.1,1.3,-0.1,1.2,101-61,-6,18-13,19-16,49-27,9-11,51-30,44-37,9-8,21-19,61-39,34-28,45-32,50-35
6,White Sox,93,69,.574,4.9,3.9,1.0,-0.2,0.8,97-65,-4,19-14,44-32,16-17,14-6,53-28,40-41,6-7,18-24,68-52,25-17,27-29,66-40
7,Red Sox,92,70,.568,5.1,4.6,0.5,0.1,0.6,88-74,4,41-35,20-13,15-18,16-4,49-32,43-38,11-5,26-18,57-39,35-31,46-48,46-22
8,Yankees,92,70,.568,4.4,4.1,0.3,0.1,0.4,86-76,6,36-40,22-10,22-12,12-8,46-35,46-35,10-8,28-20,60-46,32-24,48-43,44-27
9,Blue Jays,91,71,.562,5.2,4.1,1.1,0.0,1.2,99-63,-8,42-34,19-15,16-16,14-6,47-33,44-38,3-9,15-15,68-51,23-20,48-44,43-27
10,Cardinals,90,72,.556,4.4,4.1,0.2,-0.2,0.0,85-77,5,17-16,42-34,20-13,11-9,45-36,45-36,7-2,26-19,66-59,24-13,32-36,58-36
11,Mariners,90,72,.556,4.3,4.6,-0.3,0.1,-0.2,76-86,14,19-15,15-17,47-29,9-11,46-35,44-37,14-7,33-19,54-44,36-28,44-34,46-38
12,Braves,88,73,.547,4.9,4.1,0.8,-0.1,0.7,94-67,-6,45-31,22-12,15-16,6-14,42-38,46-35,5-9,26-31,65-55,23-18,31-37,57-36
13,Athletics,86,76,.531,4.6,4.2,0.3,0.1,0.4,87-75,-1,15-18,23-10,37-39,11-9,43-38,43-38,8-3,23-27,49-50,37-26,30-51,56-25
14,Reds,83,79,.512,4.9,4.7,0.2,-0.2,0.0,83-79,0,20-13,43-33,11-22,9-11,44-37,39-42,9-8,24-20,62-59,21-20,31-37,52-42
15,Phillies,82,80,.506,4.5,4.6,-0.1,0.0,-0.1,80-82,2,41-35,20-14,13-19,8-12,47-34,35-46,11-6,30-25,59-51,23-29,30-38,52-42
16,Indians,80,82,.494,4.4,4.5,-0.1,-0.1,-0.1,80-82,0,13-21,43-33,15-17,9-11,40-41,40-41,7-9,17-22,51-52,29-30,28-51,52-31
17,Padres,79,83,.488,4.5,4.4,0.1,0.1,0.2,83-79,-4,15-18,16-17,34-42,14-6,45-36,34-47,8-8,21-26,55-63,24-20,39-44,40-39
18,Tigers,77,85,.475,4.3,4.7,-0.4,-0.1,-0.4,75-87,2,18-14,30-46,18-16,11-9,42-39,35-46,12-8,23-23,48-60,29-25,39-36,38-49
19,Mets,77,85,.475,3.9,4.1,-0.2,0.0,-0.2,77-85,0,39-37,13-20,16-17,9-11,47-34,30-51,11-7,31-35,59-52,18-33,33-53,44-32
20,Angels,77,85,.475,4.5,5.0,-0.5,0.2,-0.3,73-89,4,16-17,21-12,29-47,11-9,40-42,37-43,3-5,25-14,47-60,30-25,39-62,38-23
21,Rockies,74,87,.460,4.6,4.9,-0.4,0.1,-0.2,75-86,-1,19-13,14-19,31-45,10-10,48-33,26-54,8-7,24-25,47-69,27-18,31-52,43-35
22,Royals,74,88,.457,4.2,4.9,-0.6,0.0,-0.6,71-91,3,12-21,36-40,14-19,12-8,39-42,35-46,4-5,21-19,48-64,26-24,35-44,39-44
23,Twins,73,89,.451,4.5,5.1,-0.6,0.0,-0.6,71-91,2,13-20,37-39,13-20,10-10,38-43,35-46,11-12,25-19,53-53,20-36,29-49,44-40
24,Cubs,71,91,.438,4.4,5.2,-0.8,-0.1,-0.9,68-94,3,13-21,35-41,17-15,6-14,39-42,32-49,6-7,24-27,50-67,21-24,31-60,40-31
25,Marlins,67,95,.414,3.8,4.3,-0.5,0.0,-0.5,72-90,-5,35-41,12-20,17-17,3-17,42-39,25-56,9-8,21-29,49-64,18-31,31-56,36-39
26,Nationals,65,97,.401,4.5,5.1,-0.6,0.0,-0.6,72-90,-7,30-46,14-18,11-23,10-10,35-46,30-51,2-11,22-26,47-63,18-34,27-58,38-39
27,Pirates,61,101,.377,3.8,5.1,-1.4,0.0,-1.4,58-104,3,17-17,23-53,11-21,10-10,37-44,24-57,5-3,20-22,47-65,14-36,29-59,32-42
28,Rangers,60,102,.370,3.9,5.0,-1.2,0.2,-1.0,62-100,-2,14-20,11-21,28-48,7-13,36-45,24-57,9-9,18-21,33-68,27-34,34-63,26-39
29,Orioles,52,110,.321,4.1,5.9,-1.8,0.3,-1.5,54-108,-2,20-56,10-24,15-17,7-13,27-54,25-56,4-7,13-24,30-67,22-43,30-78,22-32
30, Diamondbacks,52,110,.321,4.2,5.5,-1.3,0.2,-1.1,61-101,-9,13-21,13-19,22-54,4-16,32-49,20-61,6-10,10-31,40-75,12-35,22-63,30-47
,Average,80,80,.500,4.5,4.5,,,,81-80,,23-23,24-23,23-24,10-10,43-37,37-43,7-7,22-22,55-54,25-26,34-46,46-34
"""

info2 = StringIO(info2)

info2 = pd.read_csv(info2)

info = info.merge(info2, on='Team')

df2 = df.merge(info, on='Team')

# %%
data=df2.dropna(subset=['POP'])
data=data.dropna(subset=['City'])
df2=df2.dropna(subset=['City'])

# %%
data['Year (Ballpark)'] = data['Year (Ballpark)'].astype(int)

# convert column values to integers
data['BC'] = data['Ballpark Capacity'].str.replace(',', '').astype(int)
data['BC'] = data['BC'].astype(int)
data['POP'] = data['POP'].astype(int)
data['DAN']=data['DAN'].astype(int)
data['Year (Song)']=data['Year (Song)'].astype(int)
data['MP'] = data['Metro Pop.'].str.replace(',', '').astype(int)
data['CP'] = data['City Pop.'].str.replace(',', '').astype(int)
data['LOU'] = data['Loudness'].astype(int)
data['HAP'] = data["Happiness' "].astype(int)
data['ENE'] = data["Energy'"].astype(int)
data['lat'] = data['Latitude'].astype(int)
data['lon'] = data['Longitude'].astype(int)
data['YB']= data['Year (Ballpark)'].astype(int)
data['YS'] = data['Year (Song)'].astype(int)
data['BPM'] = data['Song BPM'].astype(int)
data['Key'] = data['Song Key'].astype(int)

# %%
data.columns
# Out:
# Index(['City', 'Team', 'League_x', 'Division', 'Ballpark', 'County',
#        'Latitude', 'Longitude', 'City (Ballpark)', 'Year (Ballpark)',
#        'Ballpark Capacity', 'Retractable Roof', 'Song', 'Song BPM', 'Song Key',
#        'Song 'Camelot'', 'Danceability'', 'Energy'', 'Popularity'',
#        'Happiness' ', 'Acousticness', 'Instrumentalness', 'Loudness',
#        'Duration ', 'Year (Song)', 'Artist (Writing)', 'City Founded',
#        'City Pop.', 'Metro Pop.', 'POP', 'DAN', 'League_y', 'Games', 'At Bats',
#        'Runs', 'Hits', 'Doubles', 'Triples', 'Homeruns', 'RBI', 'Walks',
#        'Strikeouts', 'Stolen Bases', 'Caught Stealing', 'Batting Avg',
#        'On Base %', 'Slugging %', 'On-Base plus Slugging', 'Rk', 'W', 'L',
#        'W-L%', 'R', 'RA', 'Rdiff', 'SOS', 'SRS', 'pythWL', 'Luck', 'vEast',
#        'vCent', 'vWest', 'Inter', 'Home', 'Road', 'ExInn', '1Run', 'vRHP',
#        'vLHP', '≥.500', '<.500', 'BC', 'MP', 'CP', 'LOU', 'HAP', 'ENE',
# ...

# %%
print((data['Key'].median())
# Out:
#   Input In [18]
#     print((data['Key'].median())
#                                 ^
# SyntaxError: unexpected EOF while parsing

# %%
data = data.apply(pd.to_numeric, errors='ignore')


integer_columns = data.select_dtypes(include='integer').columns
average_values = data[integer_columns].mean()


print(average_values).head()
# Out:
# Year (Ballpark)       1990.08
# Song BPM               124.24
# Danceability'           63.24
# Energy'                 75.24
# Popularity'             57.56
# Year (Song)           1991.60
# POP                     57.56
# DAN                     63.24
# Games                  161.92
# At Bats               5399.16
# Runs                   744.88
# Hits                  1318.92
# Doubles                261.16
# Triples                 21.92
# Homeruns               203.84
# RBI                    711.00
# Walks                  530.04
# Strikeouts            1408.32
# Stolen Bases            75.64
# Caught Stealing         23.96
# W                       84.76
# L                       77.16
# BC                   42094.08
# MP                 6804165.00
# CP                 1361111.12
# LOU                     -6.76
# HAP                     68.76
# ENE                     75.24
# lat                     37.44
# lon                    -93.44
# YB                    1990.08
# ...

# %%
data.plot.scatter(x='Runs', y='POP')
# Out:
# <AxesSubplot:xlabel='Runs', ylabel='POP'>

# %%
data.plot.scatter(x='Runs', y='POP')
# Out:
# <AxesSubplot:xlabel='Runs', ylabel='POP'>

# %%
data.plot.scatter(x='Batting Avg', y='POP')
# Out:
# <AxesSubplot:xlabel='Batting Avg', ylabel='POP'>

# %%
data.plot.scatter(x='CP', y='POP') #
# Out:
# <AxesSubplot:xlabel='CP', ylabel='POP'>

# %%
data.plot.scatter(x='CP', y='DAN') #
# Out:
# <AxesSubplot:xlabel='CP', ylabel='DAN'>

# %%
data['Duration'] = pd.to_timedelta('00:' + data['Duration '])
data['Duration_seconds'] = data['Duration'].dt.total_seconds()

# %%
data.plot.scatter(x='LOU', y='BC') #
# Out:
# <AxesSubplot:xlabel='LOU', ylabel='BC'>

# %%
ax = data.plot.scatter(x='HAP', y='Runs', c='orange')
data.plot.scatter(x='HAP', y='Homeruns', ax=ax, figsize=(5,10), ylabel='Runs (Homeruns in blue)', legend=True) #
# Out:
# <AxesSubplot:xlabel='HAP', ylabel='Runs (Homeruns in blue)'>

# %%
data.plot.scatter(x='HAP', y='Homeruns')
# Out:
# <AxesSubplot:xlabel='HAP', ylabel='Homeruns'>

# %%
data.plot.scatter(x='ENE', y='Runs')
# Out:
# <AxesSubplot:xlabel='ENE', ylabel='Runs'>

# %%
data.plot.scatter(x='ENE', y='Hits') #
# Out:
# <AxesSubplot:xlabel='ENE', ylabel='Hits'>

# %%
data['ANGST']=data['HAP']-data['ENE']
data[['Song', 'ANGST','Luck']]
# Out:
#                                                  Song  ANGST  Luck
# 0                                 You Make My Dreams      40   2.0
# 1                                       Paradise City    -58   4.0
# 2   Baby Wants to Ride (DJ Isaac extended vocal re...    -39   5.0
# 3                                     New York Groove     24   0.0
# 4                                           Celebrate      8   2.0
# 5                                              Song 2     13   2.0
# 6                                  Rocky Mountain Way      4  -1.0
# 7                                           I Love LA    -12  -3.0
# 8                                         Dirty Water      8   4.0
# 9                                        I Like Texas      2  -2.0
# 10                                        Unstoppable    -43   0.0
# 11                               Don't Stop the Party     -1  -4.0
# 12                                        Kansas City     20   3.0
# ...

# %%
data.plot.scatter(x='ANGST', y='Hits')
# Out:
# <AxesSubplot:xlabel='ANGST', ylabel='Hits'>

# %%
scatter_with_regression(data, 'ANGST', 'Hits')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Slope:  -0.6588568557309337
# Intercept:  1314.6506075748637
# R-value:  -0.258139848811193
# P-value:  0.2128131163966432
# Is statistically significant?  False

# %%
data.plot.scatter(x='W-L%', y='HAP')
# Out:
# <AxesSubplot:xlabel='W-L%', ylabel='HAP'>

# %%
data.plot.scatter(x='W-L%', y='DAN')
# Out:
# <AxesSubplot:xlabel='W-L%', ylabel='DAN'>

# %%
data.plot.scatter(x='POP', y='lat')
# Out:
# <AxesSubplot:xlabel='POP', ylabel='lat'>

# %%
data.plot.scatter(x='lon', y='POP')
# Out:
# <AxesSubplot:xlabel='lon', ylabel='POP'>

# %%
data.plot.scatter(x='lon', y='DAN')
# Out:
# <AxesSubplot:xlabel='lon', ylabel='DAN'>

# %%
data[data['DAN']<50]
# Out:
#            City      Team  League_x  Division        Ballpark       County  \
# 1   Los Angeles    Angels       NaN       NaN   Angel Stadium  Los Angeles
# 6      Colorado   Rockies       NaN       NaN     Coors Field       Denver
# 8        Boston   Red Sox       NaN       NaN     Fenway Park      Suffolk
# 19    San Diego    Padres       NaN       NaN      Petco Park    San Diego
# 22      Seattle  Mariners       NaN       NaN   T-mobile Park         King
# 27     New York   Yankees       NaN       NaN  Yankee Stadium        Bronx
#
#      Latitude   Longitude City (Ballpark)  Year (Ballpark)  ...        MP  \
# 1   33.800308 -117.882732     Anaheim, CA             1966  ...  13200998
# 6   39.755882 -104.994178      Denver, CO             1995  ...   2963821
# 8   42.346676  -71.097218      Boston, MA             1912  ...   4941632
# 19  32.707603 -117.156600   San Diego, CA             2004  ...   3298634
# ...

# %%
data.plot.scatter(x='POP', y='MP')
# Out:
# <AxesSubplot:xlabel='POP', ylabel='MP'>

# %%
data.plot.scatter(x='YB', y='YS')
# Out:
# <AxesSubplot:xlabel='YB', ylabel='YS'>

# %%
scatter_with_regression(data, 'YS', 'ENE')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Slope:  0.5010718424101972
# Intercept:  -922.6946813441486
# R-value:  0.5183037654005599
# P-value:  0.00794921537222097
# Is statistically significant?  True

# %%
data.plot.scatter(x='HAP', y='W-L%')
# Out:
# <AxesSubplot:xlabel='HAP', ylabel='W-L%'>

# %%
from scipy.stats import linregress

import matplotlib.pyplot as plt
from scipy import stats
from scipy.stats import linregress
import seaborn as sns

def scatter_with_regression(df, x_column, y_column):
    
   
    slope, intercept, r_value, p_value, std_err = linregress(df[x_column], df[y_column])
    line = slope * df[x_column] + intercept

  
    sns.set_style("whitegrid")  
    plt.figure(figsize=(10,6))
    plt.scatter(df[x_column], df[y_column], color='darkblue')
    plt.plot(df[x_column], line, 'r', label=f'y={slope:.2f}x+{intercept:.2f}', linewidth=2.5)

 
    plt.xlabel(x_column, fontsize=14)
    plt.ylabel(y_column, fontsize=14)
    plt.title(f'{x_column} vs {y_column}', fontsize=16)
    plt.legend(fontsize=12)
    plt.savefig(f'{x_column} vs {y_column}.pdf', format = 'pdf')
    plt.savefig(f'{x_column} vs {y_column}.jpg', format = 'jpg')

 
    plt.show()



    significance_level = 0.05
    is_significant = p_value < significance_level

    
    print('Slope: ', slope)
    print('Intercept: ', intercept)
    print('R-value: ', r_value)
    print('P-value: ', p_value)
    print('Is statistically significant? ', is_significant)


    plt.legend()
    plt.show()

# %%
scatter_with_regression(data, 'LOU', 'BC')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Slope:  -531.4616209262435
# Intercept:  38501.3994425386
# R-value:  -0.2666372103881176
# P-value:  0.19760420035553547
# Is statistically significant?  False

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [163], in <cell line: 1>()
# ----> 1 plot1.plot
#
# AttributeError: 'NoneType' object has no attribute 'plot'

# %%
scatter_with_regression(data, 'W-L%', 'BPM')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Slope:  86.78735470156906
# Intercept:  78.81202705501069
# R-value:  0.27671446440426517
# P-value:  0.18055082156548813
# Is statistically significant?  False

# %%
scatter_with_regression(data, 'W-L%', 'ENE')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Slope:  44.677630216584795
# Intercept:  51.85394123943085
# R-value:  0.1991911285411844
# P-value:  0.3397906021970739
# Is statistically significant?  False

# %%
scatter_with_regression(data, 'YB', 'BPM')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Slope:  0.06629865036880203
# Intercept:  -7.699618125945548
# R-value:  0.08064138504761514
# P-value:  0.7015794021385997
# Is statistically significant?  False

# %%
scatter_with_regression(data, 'lon', 'DAN')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Slope:  0.181564536855876
# Intercept:  80.20539032381305
# R-value:  0.18018264428718267
# P-value:  0.38875598061345007
# Is statistically significant?  False

# %%
scatter_with_regression(data, 'W-L%', 'BPM')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Slope:  86.78735470156906
# Intercept:  78.81202705501069
# R-value:  0.27671446440426517
# P-value:  0.18055082156548813
# Is statistically significant?  False

# %%
scatter_with_regression(data, 'Hits', 'ENE')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Slope:  0.062241180683127346
# Intercept:  -6.851138026590334
# R-value:  0.260525725641215
# P-value:  0.20846549346840754
# Is statistically significant?  False

# %%
scatter_with_regression(data, 'CP', 'POP')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Slope:  3.1148049386923793e-06
# Intercept:  53.320404361314885
# R-value:  0.16354562301046618
# P-value:  0.4347173256048291
# Is statistically significant?  False

# %%
scatter_with_regression(data, 'Homeruns', 'HAP')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Slope:  -0.26665118183030767
# Intercept:  123.11417690428992
# R-value:  -0.3555568055418178
# P-value:  0.08110956624756623
# Is statistically significant?  False

# %%
data.columns
# Out:
# Index(['City', 'Team', 'League_x', 'Division', 'Ballpark', 'County',
#        'Latitude', 'Longitude', 'City (Ballpark)', 'Year (Ballpark)',
#        'Ballpark Capacity', 'Retractable Roof', 'Song', 'Song BPM', 'Song Key',
#        'Song 'Camelot'', 'Danceability'', 'Energy'', 'Popularity'',
#        'Happiness' ', 'Acousticness', 'Instrumentalness', 'Loudness',
#        'Duration ', 'Year (Song)', 'Artist (Writing)', 'City Founded',
#        'City Pop.', 'Metro Pop.', 'POP', 'DAN', 'League_y', 'Games', 'At Bats',
#        'Runs', 'Hits', 'Doubles', 'Triples', 'Homeruns', 'RBI', 'Walks',
#        'Strikeouts', 'Stolen Bases', 'Caught Stealing', 'Batting Avg',
#        'On Base %', 'Slugging %', 'On-Base plus Slugging', 'Rk', 'W', 'L',
#        'W-L%', 'R', 'RA', 'Rdiff', 'SOS', 'SRS', 'pythWL', 'Luck', 'vEast',
#        'vCent', 'vWest', 'Inter', 'Home', 'Road', 'ExInn', '1Run', 'vRHP',
#        'vLHP', '≥.500', '<.500', 'BC', 'MP', 'CP', 'LOU', 'HAP', 'ENE',
# ...

# %%
def find_correlations(df, lower_threshold, upper_threshold):
    corr_matrix = data.corr().abs()  
    upper_triangle = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(bool))
    
    strong_correlations = upper_triangle.stack().nlargest(15) 
    for correlation in strong_correlations.items():
        columns, corr_value = correlation
        column1, column2 = columns

        if lower_threshold <= corr_value < upper_threshold:  
            scatter_with_regression(df, column1, column2)

# %%
find_strongest_correlations(data,0, 1)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Slope:  -0.006173116694796396
# Intercept:  0.9997576841704898
# R-value:  -0.9999409689627896
# P-value:  1.110460001291981e-46
# Is statistically significant?  True
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Slope:  0.006160802235271831
# Intercept:  0.0012504025383596185
# R-value:  0.9999014479346136
# P-value:  4.0285722145992524e-44
# Is statistically significant?  True
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Slope:  1.0017629712100813
# Intercept:  0.612218439156166
# R-value:  0.9998472383088166
# P-value:  6.223687797270021e-42
# Is statistically significant?  True
# ...

# %%
scatter_with_regression(data, 'CP', 'POP')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Slope:  3.1148049386923793e-06
# Intercept:  53.320404361314885
# R-value:  0.16354562301046618
# P-value:  0.4347173256048291
# Is statistically significant?  False

# %%
scatter_with_regression(data, 'lon', 'HAP')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Slope:  0.4294198687150514
# Intercept:  108.8849925327344
# R-value:  0.3609108399894623
# P-value:  0.07631799627903661
# Is statistically significant?  False

# %%
scatter_with_regression(data, 'YS', 'ENE')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Slope:  0.5010718424101972
# Intercept:  -922.6946813441486
# R-value:  0.5183037654005599
# P-value:  0.00794921537222097
# Is statistically significant?  True
